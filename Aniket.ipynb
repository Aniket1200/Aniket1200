# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket1200/Aniket1200/blob/main/Aniket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

mylist = [50, 100, 200, 400, 600, 1000]

res = pd.Series(mylist)

print("series = \n",res)
# Out:
# series =
#  0      50
# 1     100
# 2     200
# 3     400
# 4     600
# 5    1000
# dtype: int64

# %%
path="/content/drive/MyDrive/Colab Notebooks/03-iris.csv"

df=pd.read_csv(path)

df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['sepal length (cm)'].plot(kind='hist', bins=20, title='sepal length (cm)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['sepal width (cm)'].plot(kind='hist', bins=20, title='sepal width (cm)')
# ...

# %%
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='sepal width (cm)', y='petal length (cm)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/Colab Notebooks/Rainfall data(Seasonal indices).csv"

df=pd.read_csv(path)

df.head(24)
# Out:
#       YEAR  QUARTER  RAINFALL(Yt)     Y^t  Yt/Y^t
# 0   2015.0        1         0.564   9.703  0.0581
# 1      NaN        2        23.211   9.862  2.3535
# 2      NaN        3        22.050  10.021  2.2004
# 3      NaN        4         0.544  10.180  0.0535
# 4   2016.0        5         1.922  10.339  0.1859
# 5      NaN        6        19.455  10.498  1.8533
# 6      NaN        7        17.832  10.656  1.6734
# 7      NaN        8         2.434  10.815  0.2250
# 8   2017.0        9         0.968  10.974  0.0882
# 9      NaN       10        12.455  11.133  1.1187
# 10     NaN       11        27.883  11.292  2.4694
# 11     NaN       12         3.384  11.451  0.2955
# 12  2018.0       13         0.506  11.609  0.0436
# 13     NaN       14        17.225  11.768  1.4637
# 14     NaN       15        20.340  11.927  1.7054
# 15     NaN       16         0.448  12.086  0.0371
# 16  2019.0       17         0.994  12.245  0.0812
# 17     NaN       18        13.167  12.403  1.0615
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['QUARTER']
  ys = series['RAINFALL(Yt)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_35.sort_values('QUARTER', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('QUARTER')
_ = plt.ylabel('RAINFALL(Yt)')

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !ls /bin
# Out:
# '['				      mknod
#  7z				      mktemp
#  7za				      mm2gv
#  7zr				      more
#  aclocal			      mount
#  aclocal-1.16			      mountpoint
#  acyclic			      mpexpand
#  add-apt-repository		      mpic++
#  addpart			      mpicc
#  addr2line			      mpiCC
#  aggregate_profile		      mpicc.openmpi
#  apropos			      mpiCC.openmpi
#  apt				      mpic++.openmpi
#  apt-add-repository		      mpicxx
#  apt-cache			      mpicxx.openmpi
#  apt-cdrom			      mpiexec
#  apt-config			      mpiexec.openmpi
#  apt-extracttemplates		      mpif77
#  apt-ftparchive			      mpif77.openmpi
#  apt-get			      mpif90
#  apt-key			      mpif90.openmpi
#  apt-mark			      mpifort
#  apt-sortpkgs			      mpifort.openmpi
#  ar				      mpijavac
#  arch				      mpijavac.pl
#  as				      mpirun
#  asan_symbolize			      mpirun.openmpi
#  asan_symbolize-14		      mv
#  autoconf			      mysql_config
#  autoheader			      namei
#  autom4te			      nawk
#  automake			      nc-config
# ...

# %%
# !wget "C:\Users\LENOVO\Downloads\annual-enterprise-survey-2021-financial-year-provisional-csv.csv"

# %%
# !pwd
# Out:
# /content

# %%
# !date
# Out:
# Sun Mar  3 06:00:44 PM UTC 2024

# %%
# !wget https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv
# Out:
# --2024-03-03 18:04:59--  https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv
# Resolving www.stats.govt.nz (www.stats.govt.nz)... 45.60.15.104
# Connecting to www.stats.govt.nz (www.stats.govt.nz)|45.60.15.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6617174 (6.3M) [text/csv]
# Saving to: ‘annual-enterprise-survey-2021-financial-year-provisional-csv.csv’
#
# annual-enterprise-s 100%[===================>]   6.31M  --.-KB/s    in 0.04s
#
# 2024-03-03 18:05:00 (148 MB/s) - ‘annual-enterprise-survey-2021-financial-year-provisional-csv.csv’ saved [6617174/6617174]

# %%
import pandas as pd

# %%
mylist = [20, 30, 40, 50, 60, 70, 80,]

res=pd.Series(mylist)

print("series = \n",res)
# Out:
# series =
#  0    20
# 1    30
# 2    40
# 3    50
# 4    60
# 5    70
# 6    80
# dtype: int64

# %%
# !wget https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv
# Out:
# --2024-03-03 20:15:40--  https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv
# Resolving www.stats.govt.nz (www.stats.govt.nz)... 45.60.11.104
# Connecting to www.stats.govt.nz (www.stats.govt.nz)|45.60.11.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6617174 (6.3M) [text/csv]
# Saving to: ‘annual-enterprise-survey-2021-financial-year-provisional-csv.csv’
#
# annual-enterprise-s 100%[===================>]   6.31M  --.-KB/s    in 0.04s
#
# 2024-03-03 20:15:41 (142 MB/s) - ‘annual-enterprise-survey-2021-financial-year-provisional-csv.csv’ saved [6617174/6617174]

# %%
path="/content/annual-enterprise-survey-2021-financial-year-provisional-csv.csv"

Aniket=pd.read_csv(path)

Aniket.head(40000)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 39995  2013                     Level 4                II131
# 39996  2013                     Level 4                II131
# 39997  2013                     Level 4                II131
# 39998  2013                     Level 4                II131
# 39999  2013                     Level 4                II131
#
#                                    Industry_name_NZSIOC               Units  \
# 0                                        All industries  Dollars (millions)
# 1                                        All industries  Dollars (millions)
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## **My friend circle**

# %% [markdown]
# 1.   Aniket
# 2.   Sayan
# 3.   Pratik
# 4.   Babai
# 5.   Rupanjan

# %% [markdown]
# [NASA](https://www.nasa.gov/history/womens-history-month-celebrating-women-astronauts-2024/)

# %% [markdown]
# ```
# # This is formatted as code
# import pandas as pd
# print("Mithu")
#
# ```

# %% [markdown]
# $ x^2 +2ab+b^2 $

# %% [markdown]
# $x= \frac{-b +\sqrt(b^2 - 4ac)}{2a}$

# %% [markdown]
# $x= \frac{a^2}{b^2}$
